# %%
# -*- coding: utf-8 -*-
"""
Created on Sat May 13 06:44:04 2023

@author: manis
"""

from random import seed
from random import randint
from numpy import array
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from math import sqrt
from sklearn.metrics import mean_squared_error

def product(x,y):
   return (x*y)

# generate examples of random integers and their product
def random_product_pairs(n_examples, n_numbers, largest):
    X, y = list(), list()
    for i in range(n_examples):
        in_pattern = [randint(1,largest) for _ in range(n_numbers)]
        out_pattern = product(in_pattern[0],in_pattern[1])
        X.append(in_pattern)
        y.append(out_pattern)
    # format as NumPy arrays
    X,y = array(X), array(y)
    # normalize
    X = X.astype('float') / float(largest * n_numbers)
    y = y.astype('float') / float(largest * n_numbers)
    return X, y

# invert normalization
def invert(value, n_numbers, largest):
    return round(value * float(largest * n_numbers))

# generate training data
seed(1)
n_examples1 = 100
n_examples2 = 10
n_numbers = 2
largest = 100
# define LSTM configuration
n_batch = 1
n_epoch = 200
# create LSTM
model = Sequential()
model.add(LSTM(10, input_shape=(n_numbers, 1)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
# train LSTM
for _ in range(n_epoch):
    X, y = random_product_pairs(n_examples1, n_numbers, largest)
    XX = X.reshape(n_examples1, n_numbers, 1)
    model.fit(XX, y, epochs=1, batch_size=n_batch, verbose=2)
# evaluate on some new patterns
X, y = random_product_pairs(n_examples2,n_numbers,largest)
myX = X*largest*n_numbers
myy = y*largest*n_numbers
XX = X.reshape(n_examples2, n_numbers, 1)
result = model.predict(XX, batch_size=n_batch, verbose=0)
# calculate error
expected = [invert(x, n_numbers, largest) for x in y]
predicted = [invert(x, n_numbers, largest) for x in result[:,0]]
rmse = sqrt(mean_squared_error(expected, predicted))
print('RMSE: %f' % rmse)
# show some examples
for i in range(10):
    error = expected[i]-predicted[i]
    print('%d X %d = %d, Predicted=%d (err=%d)' %(myX[i][0],myX[i][1],expected[i], predicted[i], error))
# Out:
# 100/100 - 4s - loss: 311.0736 - 4s/epoch - 39ms/step
# 100/100 - 0s - loss: 217.3192 - 354ms/epoch - 4ms/step
# 100/100 - 0s - loss: 219.1699 - 355ms/epoch - 4ms/step
# 100/100 - 0s - loss: 277.9450 - 367ms/epoch - 4ms/step
# 100/100 - 0s - loss: 182.5259 - 369ms/epoch - 4ms/step
# 100/100 - 0s - loss: 145.9647 - 334ms/epoch - 3ms/step
# 100/100 - 0s - loss: 159.0444 - 332ms/epoch - 3ms/step
# 100/100 - 0s - loss: 140.7624 - 334ms/epoch - 3ms/step
# 100/100 - 0s - loss: 128.0283 - 351ms/epoch - 4ms/step
# 100/100 - 0s - loss: 129.4905 - 296ms/epoch - 3ms/step
# 100/100 - 0s - loss: 113.5535 - 302ms/epoch - 3ms/step
# 100/100 - 0s - loss: 108.7128 - 292ms/epoch - 3ms/step
# 100/100 - 0s - loss: 160.9333 - 262ms/epoch - 3ms/step
# 100/100 - 0s - loss: 75.7708 - 245ms/epoch - 2ms/step
# 100/100 - 0s - loss: 128.7708 - 282ms/epoch - 3ms/step
# 100/100 - 0s - loss: 76.7287 - 270ms/epoch - 3ms/step
# 100/100 - 0s - loss: 97.0557 - 300ms/epoch - 3ms/step
# 100/100 - 0s - loss: 122.2684 - 300ms/epoch - 3ms/step
# 100/100 - 0s - loss: 140.1850 - 365ms/epoch - 4ms/step
# 100/100 - 0s - loss: 87.4289 - 330ms/epoch - 3ms/step
# 100/100 - 0s - loss: 105.8274 - 357ms/epoch - 4ms/step
# 100/100 - 0s - loss: 145.4210 - 333ms/epoch - 3ms/step
# 100/100 - 0s - loss: 144.2446 - 391ms/epoch - 4ms/step
# 100/100 - 0s - loss: 88.3156 - 334ms/epoch - 3ms/step
# 100/100 - 0s - loss: 120.5908 - 331ms/epoch - 3ms/step
# 100/100 - 0s - loss: 92.6660 - 330ms/epoch - 3ms/step
# 100/100 - 0s - loss: 93.7972 - 317ms/epoch - 3ms/step
# 100/100 - 0s - loss: 89.5904 - 334ms/epoch - 3ms/step
# 100/100 - 0s - loss: 107.7190 - 328ms/epoch - 3ms/step
# 100/100 - 0s - loss: 84.1885 - 347ms/epoch - 3ms/step
# 100/100 - 0s - loss: 88.4274 - 333ms/epoch - 3ms/step
# 100/100 - 0s - loss: 90.0763 - 331ms/epoch - 3ms/step
# 100/100 - 0s - loss: 78.1835 - 315ms/epoch - 3ms/step
# 100/100 - 0s - loss: 86.3974 - 316ms/epoch - 3ms/step
# 100/100 - 0s - loss: 67.5919 - 334ms/epoch - 3ms/step
# 100/100 - 0s - loss: 93.7773 - 332ms/epoch - 3ms/step
# 100/100 - 0s - loss: 72.4598 - 350ms/epoch - 4ms/step
# 100/100 - 0s - loss: 90.9901 - 346ms/epoch - 3ms/step
# 100/100 - 0s - loss: 91.1647 - 325ms/epoch - 3ms/step
# 100/100 - 0s - loss: 62.5332 - 284ms/epoch - 3ms/step
# 100/100 - 0s - loss: 68.8553 - 334ms/epoch - 3ms/step
# 100/100 - 0s - loss: 97.8646 - 340ms/epoch - 3ms/step
# 100/100 - 0s - loss: 74.1703 - 327ms/epoch - 3ms/step
# 100/100 - 0s - loss: 68.4883 - 315ms/epoch - 3ms/step
# 100/100 - 0s - loss: 71.4120 - 349ms/epoch - 3ms/step
# 100/100 - 0s - loss: 86.6162 - 330ms/epoch - 3ms/step
# 100/100 - 0s - loss: 60.2137 - 334ms/epoch - 3ms/step
# 100/100 - 0s - loss: 73.3372 - 261ms/epoch - 3ms/step
# 100/100 - 0s - loss: 62.0334 - 296ms/epoch - 3ms/step
# 100/100 - 0s - loss: 74.1972 - 249ms/epoch - 2ms/step
# 100/100 - 0s - loss: 52.6389 - 254ms/epoch - 3ms/step
# 100/100 - 0s - loss: 73.5420 - 323ms/epoch - 3ms/step
# 100/100 - 0s - loss: 49.6042 - 258ms/epoch - 3ms/step
# 100/100 - 0s - loss: 82.5358 - 290ms/epoch - 3ms/step
# 100/100 - 0s - loss: 75.1562 - 346ms/epoch - 3ms/step
# 100/100 - 0s - loss: 45.6735 - 334ms/epoch - 3ms/step
# 100/100 - 0s - loss: 39.4504 - 331ms/epoch - 3ms/step
# 100/100 - 0s - loss: 50.1741 - 315ms/epoch - 3ms/step
# 100/100 - 0s - loss: 43.2263 - 317ms/epoch - 3ms/step
# 100/100 - 0s - loss: 47.8029 - 333ms/epoch - 3ms/step
# 100/100 - 0s - loss: 56.8878 - 348ms/epoch - 3ms/step
# 100/100 - 0s - loss: 39.0109 - 331ms/epoch - 3ms/step
# 100/100 - 0s - loss: 26.3803 - 330ms/epoch - 3ms/step
# 100/100 - 0s - loss: 44.2148 - 243ms/epoch - 2ms/step
# 100/100 - 0s - loss: 41.5107 - 256ms/epoch - 3ms/step
# 100/100 - 0s - loss: 38.3881 - 257ms/epoch - 3ms/step
# 100/100 - 0s - loss: 44.7987 - 245ms/epoch - 2ms/step
# 100/100 - 0s - loss: 43.7663 - 267ms/epoch - 3ms/step
# 100/100 - 0s - loss: 39.4399 - 262ms/epoch - 3ms/step
# 100/100 - 0s - loss: 25.5566 - 243ms/epoch - 2ms/step
# 100/100 - 0s - loss: 30.5935 - 242ms/epoch - 2ms/step
# 100/100 - 0s - loss: 30.9861 - 302ms/epoch - 3ms/step
# 100/100 - 0s - loss: 30.4689 - 270ms/epoch - 3ms/step
# 100/100 - 0s - loss: 35.2996 - 263ms/epoch - 3ms/step
# 100/100 - 0s - loss: 39.2236 - 286ms/epoch - 3ms/step
# 100/100 - 0s - loss: 19.7611 - 348ms/epoch - 3ms/step
# 100/100 - 0s - loss: 31.8133 - 347ms/epoch - 3ms/step
# 100/100 - 0s - loss: 31.0212 - 420ms/epoch - 4ms/step
# 100/100 - 0s - loss: 19.8977 - 356ms/epoch - 4ms/step
# 100/100 - 0s - loss: 42.8782 - 321ms/epoch - 3ms/step
# 100/100 - 0s - loss: 20.3691 - 294ms/epoch - 3ms/step
# 100/100 - 0s - loss: 28.4372 - 312ms/epoch - 3ms/step
# 100/100 - 0s - loss: 29.9940 - 263ms/epoch - 3ms/step
# 100/100 - 0s - loss: 29.6863 - 309ms/epoch - 3ms/step
# 100/100 - 0s - loss: 20.2996 - 425ms/epoch - 4ms/step
# 100/100 - 0s - loss: 21.1043 - 328ms/epoch - 3ms/step
# 100/100 - 0s - loss: 21.3234 - 392ms/epoch - 4ms/step
# 100/100 - 0s - loss: 18.1226 - 261ms/epoch - 3ms/step
# 100/100 - 0s - loss: 14.7061 - 255ms/epoch - 3ms/step
# 100/100 - 0s - loss: 28.9649 - 261ms/epoch - 3ms/step
# 100/100 - 0s - loss: 17.0591 - 225ms/epoch - 2ms/step
# 100/100 - 0s - loss: 19.5732 - 259ms/epoch - 3ms/step
# 100/100 - 0s - loss: 24.8677 - 284ms/epoch - 3ms/step
# 100/100 - 0s - loss: 18.2608 - 295ms/epoch - 3ms/step
# 100/100 - 0s - loss: 19.0172 - 289ms/epoch - 3ms/step
# 100/100 - 0s - loss: 14.1346 - 360ms/epoch - 4ms/step
# 100/100 - 0s - loss: 12.4107 - 333ms/epoch - 3ms/step
# 100/100 - 0s - loss: 13.5163 - 363ms/epoch - 4ms/step
# 100/100 - 0s - loss: 18.9869 - 303ms/epoch - 3ms/step
# 100/100 - 0s - loss: 9.3483 - 319ms/epoch - 3ms/step
# 100/100 - 0s - loss: 12.4651 - 349ms/epoch - 3ms/step
# 100/100 - 0s - loss: 13.0594 - 350ms/epoch - 3ms/step
# 100/100 - 0s - loss: 10.7349 - 283ms/epoch - 3ms/step
# 100/100 - 0s - loss: 6.0554 - 333ms/epoch - 3ms/step
# 100/100 - 0s - loss: 7.3007 - 310ms/epoch - 3ms/step
# 100/100 - 0s - loss: 6.0884 - 332ms/epoch - 3ms/step
# 100/100 - 0s - loss: 8.2485 - 317ms/epoch - 3ms/step
# 100/100 - 0s - loss: 8.8625 - 267ms/epoch - 3ms/step
# 100/100 - 0s - loss: 9.6541 - 312ms/epoch - 3ms/step
# 100/100 - 0s - loss: 9.0511 - 329ms/epoch - 3ms/step
# 100/100 - 0s - loss: 8.9772 - 335ms/epoch - 3ms/step
# 100/100 - 0s - loss: 6.0821 - 250ms/epoch - 2ms/step
# 100/100 - 0s - loss: 4.8771 - 291ms/epoch - 3ms/step
# 100/100 - 0s - loss: 10.0089 - 329ms/epoch - 3ms/step
# 100/100 - 0s - loss: 8.2601 - 343ms/epoch - 3ms/step
# 100/100 - 0s - loss: 7.6075 - 265ms/epoch - 3ms/step
# 100/100 - 0s - loss: 6.3042 - 340ms/epoch - 3ms/step
# 100/100 - 0s - loss: 6.5549 - 311ms/epoch - 3ms/step
# 100/100 - 0s - loss: 7.8286 - 348ms/epoch - 3ms/step
# 100/100 - 0s - loss: 4.9849 - 347ms/epoch - 3ms/step
# 100/100 - 0s - loss: 7.3691 - 364ms/epoch - 4ms/step
# 100/100 - 0s - loss: 5.1136 - 394ms/epoch - 4ms/step
# 100/100 - 0s - loss: 7.4037 - 383ms/epoch - 4ms/step
# 100/100 - 0s - loss: 2.8305 - 304ms/epoch - 3ms/step
# 100/100 - 0s - loss: 7.3516 - 264ms/epoch - 3ms/step
# 100/100 - 0s - loss: 2.1761 - 238ms/epoch - 2ms/step
# 100/100 - 0s - loss: 3.5404 - 291ms/epoch - 3ms/step
# 100/100 - 0s - loss: 4.3614 - 293ms/epoch - 3ms/step
# 100/100 - 0s - loss: 11.8631 - 251ms/epoch - 3ms/step
# 100/100 - 0s - loss: 1.1256 - 249ms/epoch - 2ms/step
# 100/100 - 0s - loss: 2.1051 - 369ms/epoch - 4ms/step
# 100/100 - 0s - loss: 3.8941 - 384ms/epoch - 4ms/step
# 100/100 - 0s - loss: 3.4600 - 344ms/epoch - 3ms/step
# 100/100 - 0s - loss: 4.4968 - 382ms/epoch - 4ms/step
# 100/100 - 0s - loss: 2.1684 - 357ms/epoch - 4ms/step
# 100/100 - 0s - loss: 2.7039 - 341ms/epoch - 3ms/step
# 100/100 - 0s - loss: 3.6016 - 335ms/epoch - 3ms/step
# 100/100 - 0s - loss: 4.0626 - 362ms/epoch - 4ms/step
# 100/100 - 0s - loss: 1.7450 - 386ms/epoch - 4ms/step
# 100/100 - 0s - loss: 1.9374 - 368ms/epoch - 4ms/step
# 100/100 - 0s - loss: 4.0508 - 324ms/epoch - 3ms/step
# 100/100 - 0s - loss: 3.5684 - 393ms/epoch - 4ms/step
# 100/100 - 0s - loss: 3.0910 - 368ms/epoch - 4ms/step
# 100/100 - 0s - loss: 1.8860 - 377ms/epoch - 4ms/step
# 100/100 - 0s - loss: 2.9950 - 381ms/epoch - 4ms/step
# 100/100 - 0s - loss: 4.2494 - 322ms/epoch - 3ms/step
# 100/100 - 0s - loss: 1.4160 - 339ms/epoch - 3ms/step
# 100/100 - 0s - loss: 5.5476 - 339ms/epoch - 3ms/step
# 100/100 - 0s - loss: 3.7228 - 335ms/epoch - 3ms/step
# 100/100 - 0s - loss: 4.9835 - 348ms/epoch - 3ms/step
# 100/100 - 0s - loss: 1.2531 - 322ms/epoch - 3ms/step
# 100/100 - 0s - loss: 3.0959 - 322ms/epoch - 3ms/step
# 100/100 - 0s - loss: 1.1487 - 338ms/epoch - 3ms/step
# 100/100 - 0s - loss: 2.7615 - 319ms/epoch - 3ms/step
# 100/100 - 0s - loss: 2.4689 - 331ms/epoch - 3ms/step
# 100/100 - 0s - loss: 2.5036 - 333ms/epoch - 3ms/step
# 100/100 - 0s - loss: 0.7088 - 336ms/epoch - 3ms/step
# 100/100 - 0s - loss: 1.1772 - 332ms/epoch - 3ms/step
# 100/100 - 0s - loss: 1.9035 - 327ms/epoch - 3ms/step
# 100/100 - 0s - loss: 1.2589 - 324ms/epoch - 3ms/step
# 100/100 - 0s - loss: 1.0188 - 308ms/epoch - 3ms/step
# 100/100 - 0s - loss: 0.7025 - 326ms/epoch - 3ms/step
# 100/100 - 0s - loss: 2.9240 - 295ms/epoch - 3ms/step
# 100/100 - 0s - loss: 2.3326 - 351ms/epoch - 4ms/step
# 100/100 - 0s - loss: 0.6574 - 255ms/epoch - 3ms/step
# 100/100 - 0s - loss: 2.6831 - 262ms/epoch - 3ms/step
# 100/100 - 0s - loss: 1.4197 - 341ms/epoch - 3ms/step
# 100/100 - 0s - loss: 3.0481 - 366ms/epoch - 4ms/step
# 100/100 - 0s - loss: 2.0622 - 354ms/epoch - 4ms/step
# 100/100 - 0s - loss: 1.6641 - 385ms/epoch - 4ms/step
# 100/100 - 0s - loss: 1.7986 - 397ms/epoch - 4ms/step
# 100/100 - 0s - loss: 1.1556 - 401ms/epoch - 4ms/step
# 100/100 - 0s - loss: 3.0837 - 375ms/epoch - 4ms/step
# 100/100 - 0s - loss: 0.9139 - 330ms/epoch - 3ms/step
# 100/100 - 0s - loss: 1.4655 - 322ms/epoch - 3ms/step
# 100/100 - 0s - loss: 1.4251 - 336ms/epoch - 3ms/step
# 100/100 - 0s - loss: 1.2020 - 351ms/epoch - 4ms/step
# 100/100 - 0s - loss: 1.7412 - 310ms/epoch - 3ms/step
# 100/100 - 0s - loss: 0.6732 - 357ms/epoch - 4ms/step
# 100/100 - 0s - loss: 1.5809 - 368ms/epoch - 4ms/step
# 100/100 - 0s - loss: 0.2620 - 336ms/epoch - 3ms/step
# 100/100 - 0s - loss: 0.4761 - 367ms/epoch - 4ms/step
# 100/100 - 0s - loss: 2.0037 - 346ms/epoch - 3ms/step
# 100/100 - 0s - loss: 1.3050 - 328ms/epoch - 3ms/step
# 100/100 - 0s - loss: 1.0237 - 331ms/epoch - 3ms/step
# 100/100 - 0s - loss: 1.0008 - 348ms/epoch - 3ms/step
# 100/100 - 0s - loss: 1.9022 - 350ms/epoch - 3ms/step
# 100/100 - 0s - loss: 0.4637 - 347ms/epoch - 3ms/step
# 100/100 - 0s - loss: 1.0487 - 351ms/epoch - 4ms/step
# 100/100 - 0s - loss: 2.5497 - 354ms/epoch - 4ms/step
# 100/100 - 0s - loss: 1.2779 - 368ms/epoch - 4ms/step
# 100/100 - 0s - loss: 1.0087 - 495ms/epoch - 5ms/step
# 100/100 - 0s - loss: 0.6011 - 349ms/epoch - 3ms/step
# 100/100 - 0s - loss: 2.3380 - 286ms/epoch - 3ms/step
# 100/100 - 0s - loss: 0.3366 - 254ms/epoch - 3ms/step
# 100/100 - 0s - loss: 0.7847 - 255ms/epoch - 3ms/step
# 100/100 - 0s - loss: 1.4780 - 259ms/epoch - 3ms/step
# 100/100 - 0s - loss: 0.8123 - 258ms/epoch - 3ms/step
# 100/100 - 0s - loss: 1.2086 - 260ms/epoch - 3ms/step
# 100/100 - 0s - loss: 0.7553 - 260ms/epoch - 3ms/step
# RMSE: 285.263037
# 39 X 44 = 1716, Predicted=1757 (err=-41)
# 25 X 83 = 2075, Predicted=2053 (err=22)
# 72 X 51 = 3672, Predicted=3722 (err=-50)
# 33 X 56 = 1881, Predicted=1904 (err=-23)
# 2 X 66 = 132, Predicted=217 (err=-85)
# 9 X 98 = 882, Predicted=994 (err=-112)
# 9 X 80 = 720, Predicted=723 (err=-3)
# 67 X 35 = 2345, Predicted=2205 (err=140)
# 86 X 37 = 3182, Predicted=3189 (err=-7)
# 92 X 94 = 8648, Predicted=7771 (err=877)
